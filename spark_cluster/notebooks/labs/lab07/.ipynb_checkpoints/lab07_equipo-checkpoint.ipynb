# %% [markdown]
# # <center> <img src="img/ITESOLogo.png" alt="ITESO" width="480" height="130"> </center>
# # <center> **Departamento de Electrónica, Sistemas e Informática** </center>
# ---
# ## <center> **Carrera: <Coloca el nombre de tu carrera aqui>** </center>
# ---
# ### <center> **Primavera 2025** </center>
# ---
#
# **Lab 07**
#
# **Fecha**: 04/04/4045
#
# **Nombre del equipo**: Equipo 2.0
#
# **Profesor**: Pablo Camarillo Ramirez

# %%
import findspark
findspark.init()

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("SparkSQLStructuredStreaming-Files") \
    .master("spark://34ad4bc7c499:7077") \
    .config("spark.ui.port","4040") \
    .getOrCreate()
sc = spark.sparkContext

# %% [markdown]
# Java Listener

# %%
from equipo.log_listener import TrafficListener
spark.streams.addListener(TrafficListener())

# %%
log_lines = spark \
                .readStream \
                .format("text") \
                .option("maxFilesPerTrigger", 1) \
                .load("/home/jovyan/notebooks/data/log_streaming/input/")

# %%
from pyspark.sql.functions import split

log_lines.writeStream.format("console").start().awaitTermination(10)
log_df = log_df.withColumn("timestamp", log_df["logs_array"].getItem(0).cast("string"))
log_df = log_df.withColumn("level", log_df["logs_array"].getItem(1).cast("string"))
log_df = log_df.withColumn("message", log_df["logs_array"].getItem(2).cast("string"))
log_df = log_df.withColumn("server", log_df["logs_array"].getItem(3).cast("string"))

log_df.printSchema()
# Out:
# root
#  |-- logs_array: array (nullable = true)
#  |    |-- element: string (containsNull = false)
#  |-- timestamp: string (nullable = true)
#  |-- level: string (nullable = true)
#  |-- message: string (nullable = true)
#  |-- server: string (nullable = true)

# %%
log_df = log_df.filter(log_df['level'] == "ERROR")
log_df.printSchema()
# Out:
# root
#  |-- logs_array: array (nullable = true)
#  |    |-- element: string (containsNull = false)
#  |-- timestamp: string (nullable = true)
#  |-- level: string (nullable = true)
#  |-- message: string (nullable = true)
#  |-- server: string (nullable = true)

# %%
query_files = log_df \
                .writeStream \
                .outputMode("append") \
                .format("console") \
                .trigger(processingTime='10 seconds') \
                .option("path", "/home/jovyan/notebooks/data/log_streaming/output/") \
                .option("checkpointLocation", "/home/jovyan/checkpoint") \
                .start()
query_files.awaitTermination(60)
# Out:
# 25/04/04 17:01:06 WARN ResolveWriteToStream: spark.sql.adaptive.enabled is not supported in streaming DataFrames/Datasets and will be disabled.
# Query started: e4e5b7df-c42e-4f3e-917b-d16df8d1bdde
# -------------------------------------------
# Batch: 23
# -------------------------------------------
# +----------+---------+-----+-------+------+
# |logs_array|timestamp|level|message|server|
# +----------+---------+-----+-------+------+
# +----------+---------+-----+-------+------+
#
# Query made progress: {
#   "id" : "e4e5b7df-c42e-4f3e-917b-d16df8d1bdde",
#   "runId" : "ce837b10-8638-4705-966e-349f2749acbd",
#   "name" : null,
#   "timestamp" : "2025-04-04T17:01:06.874Z",
#   "batchId" : 23,
#   "numInputRows" : 65,
#   "inputRowsPerSecond" : 0.0,
#   "processedRowsPerSecond" : 25.410476935105553,
#   "durationMs" : {
#     "addBatch" : 2376,
#     "commitOffsets" : 55,
#     "getBatch" : 73,
#     "queryPlanning" : 30,
#     "triggerExecution" : 2557
#   },
#   "stateOperators" : [ ],
#   "sources" : [ {
#     "description" : "FileStreamSource[file:/home/jovyan/notebooks/data/log_streaming/input]",
#     "startOffset" : {
#       "logOffset" : 22
#     },
#     "endOffset" : {
#       "logOffset" : 23
#     },
#     "latestOffset" : null,
#     "numInputRows" : 65,
#     "inputRowsPerSecond" : 0.0,
#     "processedRowsPerSecond" : 25.410476935105553
#   } ],
#   "sink" : {
#     "description" : "org.apache.spark.sql.execution.streaming.ConsoleTable$@76a5e571",
#     "numOutputRows" : 0
#   }
# }
# ALERT: The volume of data if high (numInputRows >= 50)
# 25/04/04 17:01:12 WARN FileStreamSource: Listed 147 file(s) in 2365 ms
# -------------------------------------------
# Batch: 24
# -------------------------------------------
# +----------+---------+-----+-------+------+
# |logs_array|timestamp|level|message|server|
# +----------+---------+-----+-------+------+
# +----------+---------+-----+-------+------+
#
# Query made progress: {
#   "id" : "e4e5b7df-c42e-4f3e-917b-d16df8d1bdde",
#   "runId" : "ce837b10-8638-4705-966e-349f2749acbd",
#   "name" : null,
#   "timestamp" : "2025-04-04T17:01:10.000Z",
#   "batchId" : 24,
#   "numInputRows" : 80,
#   "inputRowsPerSecond" : 25.591810620601407,
#   "processedRowsPerSecond" : 27.12783994574432,
#   "durationMs" : {
#     "addBatch" : 326,
#     "commitOffsets" : 64,
#     "getBatch" : 55,
#     "latestOffset" : 2424,
#     "queryPlanning" : 20,
#     "triggerExecution" : 2949,
#     "walCommit" : 59
#   },
#   "stateOperators" : [ ],
#   "sources" : [ {
#     "description" : "FileStreamSource[file:/home/jovyan/notebooks/data/log_streaming/input]",
#     "startOffset" : {
#       "logOffset" : 23
#     },
#     "endOffset" : {
#       "logOffset" : 24
#     },
#     "latestOffset" : null,
#     "numInputRows" : 80,
#     "inputRowsPerSecond" : 25.591810620601407,
#     "processedRowsPerSecond" : 27.12783994574432
#   } ],
#   "sink" : {
#     "description" : "org.apache.spark.sql.execution.streaming.ConsoleTable$@76a5e571",
#     "numOutputRows" : 0
#   }
# }
# ALERT: The volume of data if high (numInputRows >= 50)
# -------------------------------------------
# Batch: 25
# -------------------------------------------
# +----------+---------+-----+-------+------+
# |logs_array|timestamp|level|message|server|
# +----------+---------+-----+-------+------+
# +----------+---------+-----+-------+------+
#
# Query made progress: {
#   "id" : "e4e5b7df-c42e-4f3e-917b-d16df8d1bdde",
#   "runId" : "ce837b10-8638-4705-966e-349f2749acbd",
#   "name" : null,
#   "timestamp" : "2025-04-04T17:01:20.000Z",
#   "batchId" : 25,
#   "numInputRows" : 41,
#   "inputRowsPerSecond" : 4.1,
#   "processedRowsPerSecond" : 79.6116504854369,
#   "durationMs" : {
#     "addBatch" : 275,
#     "commitOffsets" : 53,
#     "getBatch" : 51,
#     "latestOffset" : 55,
#     "queryPlanning" : 20,
#     "triggerExecution" : 515,
#     "walCommit" : 58
#   },
#   "stateOperators" : [ ],
#   "sources" : [ {
#     "description" : "FileStreamSource[file:/home/jovyan/notebooks/data/log_streaming/input]",
#     "startOffset" : {
#       "logOffset" : 24
#     },
#     "endOffset" : {
#       "logOffset" : 25
#     },
#     "latestOffset" : null,
#     "numInputRows" : 41,
#     "inputRowsPerSecond" : 4.1,
#     "processedRowsPerSecond" : 79.6116504854369
#   } ],
#   "sink" : {
#     "description" : "org.apache.spark.sql.execution.streaming.ConsoleTable$@76a5e571",
#     "numOutputRows" : 0
#   }
# }
# -------------------------------------------
# Batch: 26
# -------------------------------------------
# +----------+---------+-----+-------+------+
# |logs_array|timestamp|level|message|server|
# +----------+---------+-----+-------+------+
# +----------+---------+-----+-------+------+
#
# Query made progress: {
#   "id" : "e4e5b7df-c42e-4f3e-917b-d16df8d1bdde",
#   "runId" : "ce837b10-8638-4705-966e-349f2749acbd",
#   "name" : null,
#   "timestamp" : "2025-04-04T17:01:30.000Z",
#   "batchId" : 26,
#   "numInputRows" : 87,
#   "inputRowsPerSecond" : 8.7,
#   "processedRowsPerSecond" : 183.1578947368421,
#   "durationMs" : {
#     "addBatch" : 243,
#     "commitOffsets" : 54,
#     "getBatch" : 51,
#     "latestOffset" : 53,
#     "queryPlanning" : 16,
#     "triggerExecution" : 475,
#     "walCommit" : 54
#   },
#   "stateOperators" : [ ],
#   "sources" : [ {
#     "description" : "FileStreamSource[file:/home/jovyan/notebooks/data/log_streaming/input]",
#     "startOffset" : {
#       "logOffset" : 25
#     },
#     "endOffset" : {
#       "logOffset" : 26
#     },
#     "latestOffset" : null,
#     "numInputRows" : 87,
#     "inputRowsPerSecond" : 8.7,
#     "processedRowsPerSecond" : 183.1578947368421
#   } ],
#   "sink" : {
#     "description" : "org.apache.spark.sql.execution.streaming.ConsoleTable$@76a5e571",
#     "numOutputRows" : 0
#   }
# }
# ALERT: The volume of data if high (numInputRows >= 50)
# -------------------------------------------
# Batch: 27
# -------------------------------------------
# +----------+---------+-----+-------+------+
# |logs_array|timestamp|level|message|server|
# +----------+---------+-----+-------+------+
# +----------+---------+-----+-------+------+
#
# Query made progress: {
#   "id" : "e4e5b7df-c42e-4f3e-917b-d16df8d1bdde",
#   "runId" : "ce837b10-8638-4705-966e-349f2749acbd",
#   "name" : null,
#   "timestamp" : "2025-04-04T17:01:40.000Z",
#   "batchId" : 27,
#   "numInputRows" : 38,
#   "inputRowsPerSecond" : 3.8,
#   "processedRowsPerSecond" : 71.69811320754717,
#   "durationMs" : {
#     "addBatch" : 270,
#     "commitOffsets" : 60,
#     "getBatch" : 60,
#     "latestOffset" : 55,
#     "queryPlanning" : 20,
#     "triggerExecution" : 530,
#     "walCommit" : 63
#   },
#   "stateOperators" : [ ],
#   "sources" : [ {
#     "description" : "FileStreamSource[file:/home/jovyan/notebooks/data/log_streaming/input]",
#     "startOffset" : {
#       "logOffset" : 26
#     },
#     "endOffset" : {
#       "logOffset" : 27
#     },
#     "latestOffset" : null,
#     "numInputRows" : 38,
#     "inputRowsPerSecond" : 3.8,
#     "processedRowsPerSecond" : 71.69811320754717
#   } ],
#   "sink" : {
#     "description" : "org.apache.spark.sql.execution.streaming.ConsoleTable$@76a5e571",
#     "numOutputRows" : 0
#   }
# }
# -------------------------------------------
# Batch: 28
# -------------------------------------------
# +----------+---------+-----+-------+------+
# |logs_array|timestamp|level|message|server|
# +----------+---------+-----+-------+------+
# +----------+---------+-----+-------+------+
#
# Query made progress: {
#   "id" : "e4e5b7df-c42e-4f3e-917b-d16df8d1bdde",
#   "runId" : "ce837b10-8638-4705-966e-349f2749acbd",
#   "name" : null,
#   "timestamp" : "2025-04-04T17:01:50.000Z",
#   "batchId" : 28,
#   "numInputRows" : 38,
#   "inputRowsPerSecond" : 3.8,
#   "processedRowsPerSecond" : 72.93666026871401,
#   "durationMs" : {
#     "addBatch" : 269,
#     "commitOffsets" : 70,
#     "getBatch" : 49,
#     "latestOffset" : 55,
#     "queryPlanning" : 20,
#     "triggerExecution" : 521,
#     "walCommit" : 57
#   },
#   "stateOperators" : [ ],
#   "sources" : [ {
#     "description" : "FileStreamSource[file:/home/jovyan/notebooks/data/log_streaming/input]",
#     "startOffset" : {
#       "logOffset" : 27
#     },
#     "endOffset" : {
#       "logOffset" : 28
#     },
#     "latestOffset" : null,
#     "numInputRows" : 38,
#     "inputRowsPerSecond" : 3.8,
#     "processedRowsPerSecond" : 72.93666026871401
#   } ],
#   "sink" : {
#     "description" : "org.apache.spark.sql.execution.streaming.ConsoleTable$@76a5e571",
#     "numOutputRows" : 0
#   }
# }
# -------------------------------------------
# Batch: 29
# -------------------------------------------
# +----------+---------+-----+-------+------+
# |logs_array|timestamp|level|message|server|
# +----------+---------+-----+-------+------+
# +----------+---------+-----+-------+------+
#
# Query made progress: {
#   "id" : "e4e5b7df-c42e-4f3e-917b-d16df8d1bdde",
#   "runId" : "ce837b10-8638-4705-966e-349f2749acbd",
#   "name" : null,
#   "timestamp" : "2025-04-04T17:02:00.000Z",
#   "batchId" : 29,
#   "numInputRows" : 100,
#   "inputRowsPerSecond" : 10.0,
#   "processedRowsPerSecond" : 198.01980198019803,
#   "durationMs" : {
#     "addBatch" : 257,
#     "commitOffsets" : 53,
#     "getBatch" : 56,
#     "latestOffset" : 67,
#     "queryPlanning" : 15,
#     "triggerExecution" : 505,
#     "walCommit" : 55
#   },
#   "stateOperators" : [ ],
#   "sources" : [ {
#     "description" : "FileStreamSource[file:/home/jovyan/notebooks/data/log_streaming/input]",
#     "startOffset" : {
#       "logOffset" : 28
#     },
#     "endOffset" : {
#       "logOffset" : 29
#     },
#     "latestOffset" : null,
#     "numInputRows" : 100,
#     "inputRowsPerSecond" : 10.0,
#     "processedRowsPerSecond" : 198.01980198019803
#   } ],
#   "sink" : {
#     "description" : "org.apache.spark.sql.execution.streaming.ConsoleTable$@76a5e571",
#     "numOutputRows" : 0
#   }
# }
# ALERT: The volume of data if high (numInputRows >= 50)
# False
# -------------------------------------------
# Batch: 30
# -------------------------------------------
# +----------+---------+-----+-------+------+
# |logs_array|timestamp|level|message|server|
# +----------+---------+-----+-------+------+
# +----------+---------+-----+-------+------+
#
# Query made progress: {
#   "id" : "e4e5b7df-c42e-4f3e-917b-d16df8d1bdde",
#   "runId" : "ce837b10-8638-4705-966e-349f2749acbd",
#   "name" : null,
#   "timestamp" : "2025-04-04T17:02:10.001Z",
#   "batchId" : 30,
#   "numInputRows" : 38,
#   "inputRowsPerSecond" : 3.7996200379962004,
#   "processedRowsPerSecond" : 85.58558558558559,
#   "durationMs" : {
#     "addBatch" : 213,
#     "commitOffsets" : 55,
#     "getBatch" : 54,
#     "latestOffset" : 54,
#     "queryPlanning" : 12,
#     "triggerExecution" : 444,
#     "walCommit" : 54
#   },
#   "stateOperators" : [ ],
#   "sources" : [ {
#     "description" : "FileStreamSource[file:/home/jovyan/notebooks/data/log_streaming/input]",
#     "startOffset" : {
#       "logOffset" : 29
#     },
#     "endOffset" : {
#       "logOffset" : 30
#     },
#     "latestOffset" : null,
#     "numInputRows" : 38,
#     "inputRowsPerSecond" : 3.7996200379962004,
#     "processedRowsPerSecond" : 85.58558558558559
#   } ],
#   "sink" : {
#     "description" : "org.apache.spark.sql.execution.streaming.ConsoleTable$@76a5e571",
#     "numOutputRows" : 0
#   }
# }
# -------------------------------------------
# Batch: 31
# -------------------------------------------
# +----------+---------+-----+-------+------+
# |logs_array|timestamp|level|message|server|
# +----------+---------+-----+-------+------+
# +----------+---------+-----+-------+------+
#
# Query made progress: {
#   "id" : "e4e5b7df-c42e-4f3e-917b-d16df8d1bdde",
#   "runId" : "ce837b10-8638-4705-966e-349f2749acbd",
#   "name" : null,
#   "timestamp" : "2025-04-04T17:02:20.000Z",
#   "batchId" : 31,
#   "numInputRows" : 72,
#   "inputRowsPerSecond" : 7.200720072007201,
#   "processedRowsPerSecond" : 165.13761467889907,
#   "durationMs" : {
#     "addBatch" : 204,
#     "commitOffsets" : 53,
#     "getBatch" : 52,
#     "latestOffset" : 53,
#     "queryPlanning" : 16,
#     "triggerExecution" : 436,
#     "walCommit" : 56
#   },
#   "stateOperators" : [ ],
#   "sources" : [ {
#     "description" : "FileStreamSource[file:/home/jovyan/notebooks/data/log_streaming/input]",
#     "startOffset" : {
#       "logOffset" : 30
#     },
#     "endOffset" : {
#       "logOffset" : 31
#     },
#     "latestOffset" : null,
#     "numInputRows" : 72,
#     "inputRowsPerSecond" : 7.200720072007201,
#     "processedRowsPerSecond" : 165.13761467889907
#   } ],
#   "sink" : {
#     "description" : "org.apache.spark.sql.execution.streaming.ConsoleTable$@76a5e571",
#     "numOutputRows" : 0
#   }
# }
# ALERT: The volume of data if high (numInputRows >= 50)
# -------------------------------------------
# Batch: 32
# -------------------------------------------
# +----------+---------+-----+-------+------+
# |logs_array|timestamp|level|message|server|
# +----------+---------+-----+-------+------+
# +----------+---------+-----+-------+------+
#
# Query made progress: {
#   "id" : "e4e5b7df-c42e-4f3e-917b-d16df8d1bdde",
#   "runId" : "ce837b10-8638-4705-966e-349f2749acbd",
#   "name" : null,
#   "timestamp" : "2025-04-04T17:02:30.000Z",
#   "batchId" : 32,
#   "numInputRows" : 69,
#   "inputRowsPerSecond" : 6.9,
#   "processedRowsPerSecond" : 154.7085201793722,
#   "durationMs" : {
#     "addBatch" : 215,
#     "commitOffsets" : 60,
#     "getBatch" : 50,
#     "latestOffset" : 53,
#     "queryPlanning" : 13,
#     "triggerExecution" : 446,
#     "walCommit" : 54
#   },
#   "stateOperators" : [ ],
#   "sources" : [ {
#     "description" : "FileStreamSource[file:/home/jovyan/notebooks/data/log_streaming/input]",
#     "startOffset" : {
#       "logOffset" : 31
#     },
#     "endOffset" : {
#       "logOffset" : 32
#     },
#     "latestOffset" : null,
#     "numInputRows" : 69,
#     "inputRowsPerSecond" : 6.9,
#     "processedRowsPerSecond" : 154.7085201793722
#   } ],
#   "sink" : {
#     "description" : "org.apache.spark.sql.execution.streaming.ConsoleTable$@76a5e571",
#     "numOutputRows" : 0
#   }
# }
# ALERT: The volume of data if high (numInputRows >= 50)
# -------------------------------------------
# Batch: 33
# -------------------------------------------
# +----------+---------+-----+-------+------+
# |logs_array|timestamp|level|message|server|
# +----------+---------+-----+-------+------+
# +----------+---------+-----+-------+------+
#
# Query made progress: {
#   "id" : "e4e5b7df-c42e-4f3e-917b-d16df8d1bdde",
#   "runId" : "ce837b10-8638-4705-966e-349f2749acbd",
#   "name" : null,
#   "timestamp" : "2025-04-04T17:02:40.000Z",
#   "batchId" : 33,
#   "numInputRows" : 38,
#   "inputRowsPerSecond" : 3.8,
#   "processedRowsPerSecond" : 88.99297423887587,
#   "durationMs" : {
#     "addBatch" : 201,
#     "commitOffsets" : 52,
#     "getBatch" : 50,
#     "latestOffset" : 52,
#     "queryPlanning" : 19,
#     "triggerExecution" : 427,
#     "walCommit" : 50
#   },
#   "stateOperators" : [ ],
#   "sources" : [ {
#     "description" : "FileStreamSource[file:/home/jovyan/notebooks/data/log_streaming/input]",
#     "startOffset" : {
#       "logOffset" : 32
#     },
#     "endOffset" : {
#       "logOffset" : 33
#     },
#     "latestOffset" : null,
#     "numInputRows" : 38,
#     "inputRowsPerSecond" : 3.8,
#     "processedRowsPerSecond" : 88.99297423887587
#   } ],
#   "sink" : {
#     "description" : "org.apache.spark.sql.execution.streaming.ConsoleTable$@76a5e571",
#     "numOutputRows" : 0
#   }
# }
# -------------------------------------------
# Batch: 34
# -------------------------------------------
# +----------+---------+-----+-------+------+
# |logs_array|timestamp|level|message|server|
# +----------+---------+-----+-------+------+
# +----------+---------+-----+-------+------+
#
# Query made progress: {
#   "id" : "e4e5b7df-c42e-4f3e-917b-d16df8d1bdde",
#   "runId" : "ce837b10-8638-4705-966e-349f2749acbd",
#   "name" : null,
#   "timestamp" : "2025-04-04T17:02:50.000Z",
#   "batchId" : 34,
#   "numInputRows" : 92,
#   "inputRowsPerSecond" : 9.2,
#   "processedRowsPerSecond" : 220.6235011990408,
#   "durationMs" : {
#     "addBatch" : 194,
#     "commitOffsets" : 52,
#     "getBatch" : 50,
#     "latestOffset" : 52,
#     "queryPlanning" : 13,
#     "triggerExecution" : 417,
#     "walCommit" : 55
#   },
#   "stateOperators" : [ ],
#   "sources" : [ {
#     "description" : "FileStreamSource[file:/home/jovyan/notebooks/data/log_streaming/input]",
#     "startOffset" : {
#       "logOffset" : 33
#     },
#     "endOffset" : {
#       "logOffset" : 34
#     },
#     "latestOffset" : null,
#     "numInputRows" : 92,
#     "inputRowsPerSecond" : 9.2,
#     "processedRowsPerSecond" : 220.6235011990408
#   } ],
#   "sink" : {
#     "description" : "org.apache.spark.sql.execution.streaming.ConsoleTable$@76a5e571",
#     "numOutputRows" : 0
#   }
# }
# ALERT: The volume of data if high (numInputRows >= 50)
# -------------------------------------------
# Batch: 35
# -------------------------------------------
# +----------+---------+-----+-------+------+
# |logs_array|timestamp|level|message|server|
# +----------+---------+-----+-------+------+
# +----------+---------+-----+-------+------+
#
# Query made progress: {
#   "id" : "e4e5b7df-c42e-4f3e-917b-d16df8d1bdde",
#   "runId" : "ce837b10-8638-4705-966e-349f2749acbd",
#   "name" : null,
#   "timestamp" : "2025-04-04T17:03:00.000Z",
#   "batchId" : 35,
#   "numInputRows" : 70,
#   "inputRowsPerSecond" : 7.0,
#   "processedRowsPerSecond" : 167.06443914081146,
#   "durationMs" : {
#     "addBatch" : 184,
#     "commitOffsets" : 53,
#     "getBatch" : 53,
#     "latestOffset" : 61,
#     "queryPlanning" : 12,
#     "triggerExecution" : 419,
#     "walCommit" : 54
#   },
#   "stateOperators" : [ ],
#   "sources" : [ {
#     "description" : "FileStreamSource[file:/home/jovyan/notebooks/data/log_streaming/input]",
#     "startOffset" : {
#       "logOffset" : 34
#     },
#     "endOffset" : {
#       "logOffset" : 35
#     },
#     "latestOffset" : null,
#     "numInputRows" : 70,
#     "inputRowsPerSecond" : 7.0,
#     "processedRowsPerSecond" : 167.06443914081146
#   } ],
#   "sink" : {
#     "description" : "org.apache.spark.sql.execution.streaming.ConsoleTable$@76a5e571",
#     "numOutputRows" : 0
#   }
# }
# ALERT: The volume of data if high (numInputRows >= 50)
# -------------------------------------------
# Batch: 36
# -------------------------------------------
# +----------+---------+-----+-------+------+
# |logs_array|timestamp|level|message|server|
# +----------+---------+-----+-------+------+
# +----------+---------+-----+-------+------+
#
# Query made progress: {
#   "id" : "e4e5b7df-c42e-4f3e-917b-d16df8d1bdde",
#   "runId" : "ce837b10-8638-4705-966e-349f2749acbd",
#   "name" : null,
#   "timestamp" : "2025-04-04T17:03:10.001Z",
#   "batchId" : 36,
#   "numInputRows" : 42,
#   "inputRowsPerSecond" : 4.199580041995801,
#   "processedRowsPerSecond" : 97.22222222222223,
#   "durationMs" : {
#     "addBatch" : 194,
#     "commitOffsets" : 63,
#     "getBatch" : 49,
#     "latestOffset" : 55,
#     "queryPlanning" : 15,
#     "triggerExecution" : 432,
#     "walCommit" : 54
#   },
#   "stateOperators" : [ ],
#   "sources" : [ {
#     "description" : "FileStreamSource[file:/home/jovyan/notebooks/data/log_streaming/input]",
#     "startOffset" : {
#       "logOffset" : 35
#     },
#     "endOffset" : {
#       "logOffset" : 36
#     },
#     "latestOffset" : null,
#     "numInputRows" : 42,
#     "inputRowsPerSecond" : 4.199580041995801,
#     "processedRowsPerSecond" : 97.22222222222223
#   } ],
#   "sink" : {
#     "description" : "org.apache.spark.sql.execution.streaming.ConsoleTable$@76a5e571",
#     "numOutputRows" : 0
#   }
# }
# -------------------------------------------
# Batch: 37
# -------------------------------------------
# +----------+---------+-----+-------+------+
# |logs_array|timestamp|level|message|server|
# +----------+---------+-----+-------+------+
# +----------+---------+-----+-------+------+
#
# Query made progress: {
#   "id" : "e4e5b7df-c42e-4f3e-917b-d16df8d1bdde",
#   "runId" : "ce837b10-8638-4705-966e-349f2749acbd",
#   "name" : null,
#   "timestamp" : "2025-04-04T17:03:20.000Z",
#   "batchId" : 37,
#   "numInputRows" : 43,
#   "inputRowsPerSecond" : 4.3004300430043,
#   "processedRowsPerSecond" : 105.65110565110565,
#   "durationMs" : {
#     "addBatch" : 186,
#     "commitOffsets" : 54,
#     "getBatch" : 49,
#     "latestOffset" : 54,
#     "queryPlanning" : 12,
#     "triggerExecution" : 407,
#     "walCommit" : 49
#   },
#   "stateOperators" : [ ],
#   "sources" : [ {
#     "description" : "FileStreamSource[file:/home/jovyan/notebooks/data/log_streaming/input]",
#     "startOffset" : {
#       "logOffset" : 36
#     },
#     "endOffset" : {
#       "logOffset" : 37
#     },
#     "latestOffset" : null,
#     "numInputRows" : 43,
#     "inputRowsPerSecond" : 4.3004300430043,
#     "processedRowsPerSecond" : 105.65110565110565
#   } ],
#   "sink" : {
#     "description" : "org.apache.spark.sql.execution.streaming.ConsoleTable$@76a5e571",
#     "numOutputRows" : 0
#   }
# }
# -------------------------------------------
# Batch: 38
# -------------------------------------------
# +----------+---------+-----+-------+------+
# |logs_array|timestamp|level|message|server|
# +----------+---------+-----+-------+------+
# +----------+---------+-----+-------+------+
#
# Query made progress: {
#   "id" : "e4e5b7df-c42e-4f3e-917b-d16df8d1bdde",
#   "runId" : "ce837b10-8638-4705-966e-349f2749acbd",
#   "name" : null,
#   "timestamp" : "2025-04-04T17:03:30.000Z",
#   "batchId" : 38,
#   "numInputRows" : 67,
#   "inputRowsPerSecond" : 6.7,
#   "processedRowsPerSecond" : 134.80885311871228,
#   "durationMs" : {
#     "addBatch" : 263,
#     "commitOffsets" : 57,
#     "getBatch" : 57,
#     "latestOffset" : 51,
#     "queryPlanning" : 15,
#     "triggerExecution" : 497,
#     "walCommit" : 53
#   },
#   "stateOperators" : [ ],
#   "sources" : [ {
#     "description" : "FileStreamSource[file:/home/jovyan/notebooks/data/log_streaming/input]",
#     "startOffset" : {
#       "logOffset" : 37
#     },
#     "endOffset" : {
#       "logOffset" : 38
#     },
#     "latestOffset" : null,
#     "numInputRows" : 67,
#     "inputRowsPerSecond" : 6.7,
#     "processedRowsPerSecond" : 134.80885311871228
#   } ],
#   "sink" : {
#     "description" : "org.apache.spark.sql.execution.streaming.ConsoleTable$@76a5e571",
#     "numOutputRows" : 0
#   }
# }
# ALERT: The volume of data if high (numInputRows >= 50)
# -------------------------------------------
# Batch: 39
# -------------------------------------------
# +----------+---------+-----+-------+------+
# |logs_array|timestamp|level|message|server|
# +----------+---------+-----+-------+------+
# +----------+---------+-----+-------+------+
#
# Query made progress: {
#   "id" : "e4e5b7df-c42e-4f3e-917b-d16df8d1bdde",
#   "runId" : "ce837b10-8638-4705-966e-349f2749acbd",
#   "name" : null,
#   "timestamp" : "2025-04-04T17:03:40.000Z",
#   "batchId" : 39,
#   "numInputRows" : 90,
#   "inputRowsPerSecond" : 9.0,
#   "processedRowsPerSecond" : 202.24719101123594,
#   "durationMs" : {
#     "addBatch" : 210,
#     "commitOffsets" : 54,
#     "getBatch" : 50,
#     "latestOffset" : 66,
#     "queryPlanning" : 14,
#     "triggerExecution" : 445,
#     "walCommit" : 50
#   },
#   "stateOperators" : [ ],
#   "sources" : [ {
#     "description" : "FileStreamSource[file:/home/jovyan/notebooks/data/log_streaming/input]",
#     "startOffset" : {
#       "logOffset" : 38
#     },
#     "endOffset" : {
#       "logOffset" : 39
#     },
#     "latestOffset" : null,
#     "numInputRows" : 90,
#     "inputRowsPerSecond" : 9.0,
#     "processedRowsPerSecond" : 202.24719101123594
#   } ],
#   "sink" : {
#     "description" : "org.apache.spark.sql.execution.streaming.ConsoleTable$@76a5e571",
#     "numOutputRows" : 0
#   }
# }
# ALERT: The volume of data if high (numInputRows >= 50)
# -------------------------------------------
# Batch: 40
# -------------------------------------------
# +----------+---------+-----+-------+------+
# |logs_array|timestamp|level|message|server|
# +----------+---------+-----+-------+------+
# +----------+---------+-----+-------+------+
#
# Query made progress: {
#   "id" : "e4e5b7df-c42e-4f3e-917b-d16df8d1bdde",
#   "runId" : "ce837b10-8638-4705-966e-349f2749acbd",
#   "name" : null,
#   "timestamp" : "2025-04-04T17:03:50.000Z",
#   "batchId" : 40,
#   "numInputRows" : 90,
#   "inputRowsPerSecond" : 9.0,
#   "processedRowsPerSecond" : 175.78125,
#   "durationMs" : {
#     "addBatch" : 305,
#     "commitOffsets" : 65,
#     "getBatch" : 48,
#     "latestOffset" : 33,
#     "queryPlanning" : 19,
#     "triggerExecution" : 512,
#     "walCommit" : 42
#   },
#   "stateOperators" : [ ],
#   "sources" : [ {
#     "description" : "FileStreamSource[file:/home/jovyan/notebooks/data/log_streaming/input]",
#     "startOffset" : {
#       "logOffset" : 39
#     },
#     "endOffset" : {
#       "logOffset" : 40
#     },
#     "latestOffset" : null,
#     "numInputRows" : 90,
#     "inputRowsPerSecond" : 9.0,
#     "processedRowsPerSecond" : 175.78125
#   } ],
#   "sink" : {
#     "description" : "org.apache.spark.sql.execution.streaming.ConsoleTable$@76a5e571",
#     "numOutputRows" : 0
#   }
# }
# ALERT: The volume of data if high (numInputRows >= 50)
# -------------------------------------------
# Batch: 41
# -------------------------------------------
# +----------+---------+-----+-------+------+
# |logs_array|timestamp|level|message|server|
# +----------+---------+-----+-------+------+
# +----------+---------+-----+-------+------+
#
# Query made progress: {
#   "id" : "e4e5b7df-c42e-4f3e-917b-d16df8d1bdde",
#   "runId" : "ce837b10-8638-4705-966e-349f2749acbd",
#   "name" : null,
#   "timestamp" : "2025-04-04T17:04:00.000Z",
#   "batchId" : 41,
#   "numInputRows" : 80,
#   "inputRowsPerSecond" : 8.0,
#   "processedRowsPerSecond" : 159.3625498007968,
#   "durationMs" : {
#     "addBatch" : 211,
#     "commitOffsets" : 56,
#     "getBatch" : 77,
#     "latestOffset" : 73,
#     "queryPlanning" : 19,
#     "triggerExecution" : 502,
#     "walCommit" : 65
#   },
#   "stateOperators" : [ ],
#   "sources" : [ {
#     "description" : "FileStreamSource[file:/home/jovyan/notebooks/data/log_streaming/input]",
#     "startOffset" : {
#       "logOffset" : 40
#     },
#     "endOffset" : {
#       "logOffset" : 41
#     },
#     "latestOffset" : null,
#     "numInputRows" : 80,
#     "inputRowsPerSecond" : 8.0,
#     "processedRowsPerSecond" : 159.3625498007968
#   } ],
#   "sink" : {
#     "description" : "org.apache.spark.sql.execution.streaming.ConsoleTable$@76a5e571",
#     "numOutputRows" : 0
#   }
# }
# ALERT: The volume of data if high (numInputRows >= 50)
# -------------------------------------------
# Batch: 42
# -------------------------------------------
# +----------+---------+-----+-------+------+
# |logs_array|timestamp|level|message|server|
# +----------+---------+-----+-------+------+
# +----------+---------+-----+-------+------+
#
# Query made progress: {
#   "id" : "e4e5b7df-c42e-4f3e-917b-d16df8d1bdde",
#   "runId" : "ce837b10-8638-4705-966e-349f2749acbd",
#   "name" : null,
#   "timestamp" : "2025-04-04T17:04:10.000Z",
#   "batchId" : 42,
#   "numInputRows" : 59,
#   "inputRowsPerSecond" : 5.9,
#   "processedRowsPerSecond" : 119.67545638945234,
#   "durationMs" : {
#     "addBatch" : 233,
#     "commitOffsets" : 61,
#     "getBatch" : 60,
#     "latestOffset" : 67,
#     "queryPlanning" : 14,
#     "triggerExecution" : 493,
#     "walCommit" : 56
#   },
#   "stateOperators" : [ ],
#   "sources" : [ {
#     "description" : "FileStreamSource[file:/home/jovyan/notebooks/data/log_streaming/input]",
#     "startOffset" : {
#       "logOffset" : 41
#     },
#     "endOffset" : {
#       "logOffset" : 42
#     },
#     "latestOffset" : null,
#     "numInputRows" : 59,
#     "inputRowsPerSecond" : 5.9,
#     "processedRowsPerSecond" : 119.67545638945234
#   } ],
#   "sink" : {
#     "description" : "org.apache.spark.sql.execution.streaming.ConsoleTable$@76a5e571",
#     "numOutputRows" : 0
#   }
# }
# ALERT: The volume of data if high (numInputRows >= 50)
# -------------------------------------------
# Batch: 43
# -------------------------------------------
# +----------+---------+-----+-------+------+
# |logs_array|timestamp|level|message|server|
# +----------+---------+-----+-------+------+
# +----------+---------+-----+-------+------+
#
# Query made progress: {
#   "id" : "e4e5b7df-c42e-4f3e-917b-d16df8d1bdde",
#   "runId" : "ce837b10-8638-4705-966e-349f2749acbd",
#   "name" : null,
#   "timestamp" : "2025-04-04T17:04:20.000Z",
#   "batchId" : 43,
#   "numInputRows" : 99,
#   "inputRowsPerSecond" : 9.9,
#   "processedRowsPerSecond" : 180.327868852459,
#   "durationMs" : {
#     "addBatch" : 275,
#     "commitOffsets" : 70,
#     "getBatch" : 64,
#     "latestOffset" : 57,
#     "queryPlanning" : 17,
#     "triggerExecution" : 549,
#     "walCommit" : 64
#   },
#   "stateOperators" : [ ],
#   "sources" : [ {
#     "description" : "FileStreamSource[file:/home/jovyan/notebooks/data/log_streaming/input]",
#     "startOffset" : {
#       "logOffset" : 42
#     },
#     "endOffset" : {
#       "logOffset" : 43
#     },
#     "latestOffset" : null,
#     "numInputRows" : 99,
#     "inputRowsPerSecond" : 9.9,
#     "processedRowsPerSecond" : 180.327868852459
#   } ],
#   "sink" : {
#     "description" : "org.apache.spark.sql.execution.streaming.ConsoleTable$@76a5e571",
#     "numOutputRows" : 0
#   }
# }
# ALERT: The volume of data if high (numInputRows >= 50)
# -------------------------------------------
# Batch: 44
# -------------------------------------------
# +----------+---------+-----+-------+------+
# |logs_array|timestamp|level|message|server|
# +----------+---------+-----+-------+------+
# +----------+---------+-----+-------+------+
#
# Query made progress: {
#   "id" : "e4e5b7df-c42e-4f3e-917b-d16df8d1bdde",
#   "runId" : "ce837b10-8638-4705-966e-349f2749acbd",
#   "name" : null,
#   "timestamp" : "2025-04-04T17:04:30.000Z",
#   "batchId" : 44,
#   "numInputRows" : 35,
#   "inputRowsPerSecond" : 3.5,
#   "processedRowsPerSecond" : 82.3529411764706,
#   "durationMs" : {
#     "addBatch" : 198,
#     "commitOffsets" : 54,
#     "getBatch" : 53,
#     "latestOffset" : 51,
#     "queryPlanning" : 14,
#     "triggerExecution" : 425,
#     "walCommit" : 52
#   },
#   "stateOperators" : [ ],
#   "sources" : [ {
#     "description" : "FileStreamSource[file:/home/jovyan/notebooks/data/log_streaming/input]",
#     "startOffset" : {
#       "logOffset" : 43
#     },
#     "endOffset" : {
#       "logOffset" : 44
#     },
#     "latestOffset" : null,
#     "numInputRows" : 35,
#     "inputRowsPerSecond" : 3.5,
#     "processedRowsPerSecond" : 82.3529411764706
#   } ],
#   "sink" : {
#     "description" : "org.apache.spark.sql.execution.streaming.ConsoleTable$@76a5e571",
#     "numOutputRows" : 0
#   }
# }
# -------------------------------------------
# Batch: 45
# -------------------------------------------
# +----------+---------+-----+-------+------+
# |logs_array|timestamp|level|message|server|
# +----------+---------+-----+-------+------+
# +----------+---------+-----+-------+------+
#
# Query made progress: {
#   "id" : "e4e5b7df-c42e-4f3e-917b-d16df8d1bdde",
#   "runId" : "ce837b10-8638-4705-966e-349f2749acbd",
#   "name" : null,
#   "timestamp" : "2025-04-04T17:04:40.000Z",
#   "batchId" : 45,
#   "numInputRows" : 95,
#   "inputRowsPerSecond" : 9.5,
#   "processedRowsPerSecond" : 209.7130242825607,
#   "durationMs" : {
#     "addBatch" : 204,
#     "commitOffsets" : 55,
#     "getBatch" : 63,
#     "latestOffset" : 49,
#     "queryPlanning" : 13,
#     "triggerExecution" : 453,
#     "walCommit" : 67
#   },
#   "stateOperators" : [ ],
#   "sources" : [ {
#     "description" : "FileStreamSource[file:/home/jovyan/notebooks/data/log_streaming/input]",
#     "startOffset" : {
#       "logOffset" : 44
#     },
#     "endOffset" : {
#       "logOffset" : 45
#     },
#     "latestOffset" : null,
#     "numInputRows" : 95,
#     "inputRowsPerSecond" : 9.5,
#     "processedRowsPerSecond" : 209.7130242825607
#   } ],
#   "sink" : {
#     "description" : "org.apache.spark.sql.execution.streaming.ConsoleTable$@76a5e571",
#     "numOutputRows" : 0
#   }
# }
# ALERT: The volume of data if high (numInputRows >= 50)
# -------------------------------------------
# Batch: 46
# -------------------------------------------
# +----------+---------+-----+-------+------+
# |logs_array|timestamp|level|message|server|
# +----------+---------+-----+-------+------+
# +----------+---------+-----+-------+------+
#
# Query made progress: {
#   "id" : "e4e5b7df-c42e-4f3e-917b-d16df8d1bdde",
#   "runId" : "ce837b10-8638-4705-966e-349f2749acbd",
#   "name" : null,
#   "timestamp" : "2025-04-04T17:04:50.000Z",
#   "batchId" : 46,
#   "numInputRows" : 84,
#   "inputRowsPerSecond" : 8.4,
#   "processedRowsPerSecond" : 208.955223880597,
#   "durationMs" : {
#     "addBatch" : 185,
#     "commitOffsets" : 48,
#     "getBatch" : 50,
#     "latestOffset" : 51,
#     "queryPlanning" : 15,
#     "triggerExecution" : 402,
#     "walCommit" : 51
#   },
#   "stateOperators" : [ ],
#   "sources" : [ {
#     "description" : "FileStreamSource[file:/home/jovyan/notebooks/data/log_streaming/input]",
#     "startOffset" : {
#       "logOffset" : 45
#     },
#     "endOffset" : {
#       "logOffset" : 46
#     },
#     "latestOffset" : null,
#     "numInputRows" : 84,
#     "inputRowsPerSecond" : 8.4,
#     "processedRowsPerSecond" : 208.955223880597
#   } ],
#   "sink" : {
#     "description" : "org.apache.spark.sql.execution.streaming.ConsoleTable$@76a5e571",
#     "numOutputRows" : 0
#   }
# }
# ALERT: The volume of data if high (numInputRows >= 50)
# -------------------------------------------
# Batch: 47
# -------------------------------------------
# +----------+---------+-----+-------+------+
# |logs_array|timestamp|level|message|server|
# +----------+---------+-----+-------+------+
# +----------+---------+-----+-------+------+
#
# Query made progress: {
#   "id" : "e4e5b7df-c42e-4f3e-917b-d16df8d1bdde",
#   "runId" : "ce837b10-8638-4705-966e-349f2749acbd",
#   "name" : null,
#   "timestamp" : "2025-04-04T17:05:00.001Z",
#   "batchId" : 47,
#   "numInputRows" : 41,
#   "inputRowsPerSecond" : 4.099590040995901,
#   "processedRowsPerSecond" : 102.75689223057644,
#   "durationMs" : {
#     "addBatch" : 160,
#     "commitOffsets" : 51,
#     "getBatch" : 53,
#     "latestOffset" : 67,
#     "queryPlanning" : 15,
#     "triggerExecution" : 399,
#     "walCommit" : 53
#   },
#   "stateOperators" : [ ],
#   "sources" : [ {
#     "description" : "FileStreamSource[file:/home/jovyan/notebooks/data/log_streaming/input]",
#     "startOffset" : {
#       "logOffset" : 46
#     },
#     "endOffset" : {
#       "logOffset" : 47
#     },
#     "latestOffset" : null,
#     "numInputRows" : 41,
#     "inputRowsPerSecond" : 4.099590040995901,
#     "processedRowsPerSecond" : 102.75689223057644
#   } ],
#   "sink" : {
#     "description" : "org.apache.spark.sql.execution.streaming.ConsoleTable$@76a5e571",
#     "numOutputRows" : 0
#   }
# }
# -------------------------------------------
# Batch: 48
# -------------------------------------------
# +----------+---------+-----+-------+------+
# |logs_array|timestamp|level|message|server|
# +----------+---------+-----+-------+------+
# +----------+---------+-----+-------+------+
#
# Query made progress: {
#   "id" : "e4e5b7df-c42e-4f3e-917b-d16df8d1bdde",
#   "runId" : "ce837b10-8638-4705-966e-349f2749acbd",
#   "name" : null,
#   "timestamp" : "2025-04-04T17:05:10.000Z",
#   "batchId" : 48,
#   "numInputRows" : 86,
#   "inputRowsPerSecond" : 8.6008600860086,
#   "processedRowsPerSecond" : 206.73076923076923,
#   "durationMs" : {
#     "addBatch" : 178,
#     "commitOffsets" : 50,
#     "getBatch" : 70,
#     "latestOffset" : 52,
#     "queryPlanning" : 14,
#     "triggerExecution" : 416,
#     "walCommit" : 51
#   },
#   "stateOperators" : [ ],
#   "sources" : [ {
#     "description" : "FileStreamSource[file:/home/jovyan/notebooks/data/log_streaming/input]",
#     "startOffset" : {
#       "logOffset" : 47
#     },
#     "endOffset" : {
#       "logOffset" : 48
#     },
#     "latestOffset" : null,
#     "numInputRows" : 86,
#     "inputRowsPerSecond" : 8.6008600860086,
#     "processedRowsPerSecond" : 206.73076923076923
#   } ],
#   "sink" : {
#     "description" : "org.apache.spark.sql.execution.streaming.ConsoleTable$@76a5e571",
#     "numOutputRows" : 0
#   }
# }
# ALERT: The volume of data if high (numInputRows >= 50)
# -------------------------------------------
# Batch: 49
# -------------------------------------------
# +----------+---------+-----+-------+------+
# |logs_array|timestamp|level|message|server|
# +----------+---------+-----+-------+------+
# +----------+---------+-----+-------+------+
#
# Query made progress: {
#   "id" : "e4e5b7df-c42e-4f3e-917b-d16df8d1bdde",
#   "runId" : "ce837b10-8638-4705-966e-349f2749acbd",
#   "name" : null,
#   "timestamp" : "2025-04-04T17:05:20.000Z",
#   "batchId" : 49,
#   "numInputRows" : 63,
#   "inputRowsPerSecond" : 6.3,
#   "processedRowsPerSecond" : 155.55555555555554,
#   "durationMs" : {
#     "addBatch" : 177,
#     "commitOffsets" : 53,
#     "getBatch" : 50,
#     "latestOffset" : 61,
#     "queryPlanning" : 11,
#     "triggerExecution" : 405,
#     "walCommit" : 52
#   },
#   "stateOperators" : [ ],
#   "sources" : [ {
#     "description" : "FileStreamSource[file:/home/jovyan/notebooks/data/log_streaming/input]",
#     "startOffset" : {
#       "logOffset" : 48
#     },
#     "endOffset" : {
#       "logOffset" : 49
#     },
#     "latestOffset" : null,
#     "numInputRows" : 63,
#     "inputRowsPerSecond" : 6.3,
#     "processedRowsPerSecond" : 155.55555555555554
#   } ],
#   "sink" : {
#     "description" : "org.apache.spark.sql.execution.streaming.ConsoleTable$@76a5e571",
#     "numOutputRows" : 0
#   }
# }
# ALERT: The volume of data if high (numInputRows >= 50)
# -------------------------------------------
# Batch: 50
# -------------------------------------------
# +----------+---------+-----+-------+------+
# |logs_array|timestamp|level|message|server|
# +----------+---------+-----+-------+------+
# +----------+---------+-----+-------+------+
#
# Query made progress: {
#   "id" : "e4e5b7df-c42e-4f3e-917b-d16df8d1bdde",
#   "runId" : "ce837b10-8638-4705-966e-349f2749acbd",
#   "name" : null,
#   "timestamp" : "2025-04-04T17:05:30.000Z",
#   "batchId" : 50,
#   "numInputRows" : 49,
#   "inputRowsPerSecond" : 4.9,
#   "processedRowsPerSecond" : 101.03092783505154,
#   "durationMs" : {
#     "addBatch" : 217,
#     "commitOffsets" : 57,
#     "getBatch" : 65,
#     "latestOffset" : 65,
#     "queryPlanning" : 21,
#     "triggerExecution" : 485,
#     "walCommit" : 60
#   },
#   "stateOperators" : [ ],
#   "sources" : [ {
#     "description" : "FileStreamSource[file:/home/jovyan/notebooks/data/log_streaming/input]",
#     "startOffset" : {
#       "logOffset" : 49
#     },
#     "endOffset" : {
#       "logOffset" : 50
#     },
#     "latestOffset" : null,
#     "numInputRows" : 49,
#     "inputRowsPerSecond" : 4.9,
#     "processedRowsPerSecond" : 101.03092783505154
#   } ],
#   "sink" : {
#     "description" : "org.apache.spark.sql.execution.streaming.ConsoleTable$@76a5e571",
#     "numOutputRows" : 0
#   }
# }
# -------------------------------------------
# Batch: 51
# -------------------------------------------
# +----------+---------+-----+-------+------+
# |logs_array|timestamp|level|message|server|
# +----------+---------+-----+-------+------+
# +----------+---------+-----+-------+------+
#
# Query made progress: {
#   "id" : "e4e5b7df-c42e-4f3e-917b-d16df8d1bdde",
#   "runId" : "ce837b10-8638-4705-966e-349f2749acbd",
#   "name" : null,
#   "timestamp" : "2025-04-04T17:05:40.000Z",
#   "batchId" : 51,
#   "numInputRows" : 76,
#   "inputRowsPerSecond" : 7.6,
#   "processedRowsPerSecond" : 130.58419243986256,
#   "durationMs" : {
#     "addBatch" : 304,
#     "commitOffsets" : 57,
#     "getBatch" : 73,
#     "latestOffset" : 56,
#     "queryPlanning" : 27,
#     "triggerExecution" : 582,
#     "walCommit" : 61
#   },
#   "stateOperators" : [ ],
#   "sources" : [ {
#     "description" : "FileStreamSource[file:/home/jovyan/notebooks/data/log_streaming/input]",
#     "startOffset" : {
#       "logOffset" : 50
#     },
#     "endOffset" : {
#       "logOffset" : 51
#     },
#     "latestOffset" : null,
#     "numInputRows" : 76,
#     "inputRowsPerSecond" : 7.6,
#     "processedRowsPerSecond" : 130.58419243986256
#   } ],
#   "sink" : {
#     "description" : "org.apache.spark.sql.execution.streaming.ConsoleTable$@76a5e571",
#     "numOutputRows" : 0
#   }
# }
# ALERT: The volume of data if high (numInputRows >= 50)
# -------------------------------------------
# Batch: 52
# -------------------------------------------
# +----------+---------+-----+-------+------+
# |logs_array|timestamp|level|message|server|
# +----------+---------+-----+-------+------+
# +----------+---------+-----+-------+------+
#
# Query made progress: {
#   "id" : "e4e5b7df-c42e-4f3e-917b-d16df8d1bdde",
#   "runId" : "ce837b10-8638-4705-966e-349f2749acbd",
#   "name" : null,
#   "timestamp" : "2025-04-04T17:05:50.000Z",
#   "batchId" : 52,
#   "numInputRows" : 67,
#   "inputRowsPerSecond" : 6.7,
#   "processedRowsPerSecond" : 124.07407407407406,
#   "durationMs" : {
#     "addBatch" : 254,
#     "commitOffsets" : 74,
#     "getBatch" : 73,
#     "latestOffset" : 53,
#     "queryPlanning" : 26,
#     "triggerExecution" : 540,
#     "walCommit" : 58
#   },
#   "stateOperators" : [ ],
#   "sources" : [ {
#     "description" : "FileStreamSource[file:/home/jovyan/notebooks/data/log_streaming/input]",
#     "startOffset" : {
#       "logOffset" : 51
#     },
#     "endOffset" : {
#       "logOffset" : 52
#     },
#     "latestOffset" : null,
#     "numInputRows" : 67,
#     "inputRowsPerSecond" : 6.7,
#     "processedRowsPerSecond" : 124.07407407407406
#   } ],
#   "sink" : {
#     "description" : "org.apache.spark.sql.execution.streaming.ConsoleTable$@76a5e571",
#     "numOutputRows" : 0
#   }
# }
# ALERT: The volume of data if high (numInputRows >= 50)
# -------------------------------------------
# Batch: 53
# -------------------------------------------
# +----------+---------+-----+-------+------+
# |logs_array|timestamp|level|message|server|
# +----------+---------+-----+-------+------+
# +----------+---------+-----+-------+------+
#
# Query made progress: {
#   "id" : "e4e5b7df-c42e-4f3e-917b-d16df8d1bdde",
#   "runId" : "ce837b10-8638-4705-966e-349f2749acbd",
#   "name" : null,
#   "timestamp" : "2025-04-04T17:06:00.000Z",
#   "batchId" : 53,
#   "numInputRows" : 42,
#   "inputRowsPerSecond" : 4.2,
#   "processedRowsPerSecond" : 100.0,
#   "durationMs" : {
#     "addBatch" : 195,
#     "commitOffsets" : 54,
#     "getBatch" : 54,
#     "latestOffset" : 53,
#     "queryPlanning" : 11,
#     "triggerExecution" : 420,
#     "walCommit" : 51
#   },
#   "stateOperators" : [ ],
#   "sources" : [ {
#     "description" : "FileStreamSource[file:/home/jovyan/notebooks/data/log_streaming/input]",
#     "startOffset" : {
#       "logOffset" : 52
#     },
#     "endOffset" : {
#       "logOffset" : 53
#     },
#     "latestOffset" : null,
#     "numInputRows" : 42,
#     "inputRowsPerSecond" : 4.2,
#     "processedRowsPerSecond" : 100.0
#   } ],
#   "sink" : {
#     "description" : "org.apache.spark.sql.execution.streaming.ConsoleTable$@76a5e571",
#     "numOutputRows" : 0
#   }
# }
# -------------------------------------------
# Batch: 54
# -------------------------------------------
# +----------+---------+-----+-------+------+
# |logs_array|timestamp|level|message|server|
# +----------+---------+-----+-------+------+
# +----------+---------+-----+-------+------+
#
# Query made progress: {
#   "id" : "e4e5b7df-c42e-4f3e-917b-d16df8d1bdde",
#   "runId" : "ce837b10-8638-4705-966e-349f2749acbd",
#   "name" : null,
#   "timestamp" : "2025-04-04T17:06:10.001Z",
#   "batchId" : 54,
#   "numInputRows" : 94,
#   "inputRowsPerSecond" : 9.3990600939906,
#   "processedRowsPerSecond" : 199.15254237288136,
#   "durationMs" : {
#     "addBatch" : 214,
#     "commitOffsets" : 55,
#     "getBatch" : 65,
#     "latestOffset" : 59,
#     "queryPlanning" : 18,
#     "triggerExecution" : 472,
#     "walCommit" : 59
#   },
#   "stateOperators" : [ ],
#   "sources" : [ {
#     "description" : "FileStreamSource[file:/home/jovyan/notebooks/data/log_streaming/input]",
#     "startOffset" : {
#       "logOffset" : 53
#     },
#     "endOffset" : {
#       "logOffset" : 54
#     },
#     "latestOffset" : null,
#     "numInputRows" : 94,
#     "inputRowsPerSecond" : 9.3990600939906,
#     "processedRowsPerSecond" : 199.15254237288136
#   } ],
#   "sink" : {
#     "description" : "org.apache.spark.sql.execution.streaming.ConsoleTable$@76a5e571",
#     "numOutputRows" : 0
#   }
# }
# ALERT: The volume of data if high (numInputRows >= 50)

# %%
speed_df = spark \
            .read \
            .parquet("/home/jovyan/notebooks/data/log_streaming/output/")

speed_df.show(4, False)

# %%
sc.stop()
